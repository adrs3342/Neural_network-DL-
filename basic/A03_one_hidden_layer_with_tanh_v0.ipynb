# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# Your Name and PRN:
# - Name : Kumar Ankit
# - PRN  : 240840128022
# - Date : 28-11-2024

# %% [markdown]
# - **Q1**: Is this model more accurate compared to previous model?
# - ans:- The hidden-layer perceptron model achieves higher accuracy because:-
# - It is complex model whereas the previous models were liner.
# - The complex model result in better generalization.

# %% [markdown]
# -------------------------------------------------------
# - **Q2**: Prepare table by changing number of neurons in hidden layer, learning rate and observe change in results. Also comment on your results.
#
# |#|Dimension of hidden layer|Learning rate|Training Accuracy|Test Accuracy|Comment|
# |:-:|:-:|:-:|:-:|:-:|:--|
# |1|4|0.1|0.0.981|0.965|Base case|
# |2|1|0.1|0.872|0.855|model accuracy dropped because it is linear now|
# |3|10|0.1|0.983|0.96| model became a little more complex then the base|
# |4|50|0.1|0.981|0.96| model became more complex than other models number of parameters increased and the model started doing overfitting|
# |1|4|0.01|0.982|0.96|the model performed better in most of cases as compare to base model. The loss curve became stable at greater number of epoch as compare to base model|
# |2|1|0.01|0.872|0.855|same as base model's this number of hidden layer|
# |3|10|0.01|0.977|0.96|same as base model's this number of hidden layer|
# |4|50|0.01|0.977|0.96|same as base model's this number of hidden layer|
# |5|4|0.001|0.875|0.855|The model convergence became too slow i.e model is taking too much time to reach stable loss curve. That is alot of epochs are needed|
# |6|1|0.001|0.873|0.855|same as base model's this number of hidden layer|
# |7|10|0.001|0.887|0.9|same as base model's this number of hidden layer|
# |8|50|0.001|0.882|0.895|same as base model's this number of hidden layer|
# |9|4|1|0.982|0.96|the model is converging faster as compare to others i.e very less number of epochs are needed might result in less accuracy because of big step|
# |10|1|1|0.876|0.85|same as base model's this number of hidden layer|
# |11|10|1|0.983|0.96|same as base model's this number of hidden layer|
# |12|50|1|0.982|0.96|same as base model's this number of hidden layer|

# %% [markdown]
# -----------------------------------------------------------------
# - **Q3**: What lines will you change to convert it into multi-class prediction model?
#
# ans : our build_model function will work fine what we will need to change is:
# - the output layer should have logits same as the number of classes needed(multi-class).
# - make `softmax` function
# - use that softmax function in `predict` function
# - in return statement of the predict function we will need to put do argmax(axis = 1) of the variable in which you stored softmax of the output layer

# %% [markdown]
# ----------------------------------------------------------------------------
# - **Q4**: How many epochs are sufficient?
#
# - ans:- No. of epochs greatly depend upon the model and learning rate:-
# - the smaller the learning rate the more the epoch will be needed because the gradient wil take smaller steps and it will take longer time to converge
# - Similarly the greater the learning rate the less the number of epochs will be needeed
# - Aside from that number of epochs also depends upon the complexity of model the complex the model is the more number of epochs will be needed
#
# - Smaller datasets often require more epochs since the model needs repeated exposure to learn patterns effectively and vice versa.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %%
###------------------------------
### global variables
##-----------------
RANDOM_STATE = 24
np.random.RandomState(seed = RANDOM_STATE)

N_SAMPLE  = 1000
NOISE = .2
ALPHA = .1
TEST_SIZE = .2
EPOCHS = 100000 #NO. of itersation used to optimize weights
# input and output directories

params = {'legend.fontsize' : 'medium', 
          'figure.figsize' : (15, 4),
          'axes.labelsize' : 'medium',
          'axes.titlesize' : 'large',
          'xtick.labelsize' : 'medium',
          'ytick.labelsize' : 'medium',
         }
loss_hist = {} # creating an empty dictionary which will store loss and epoch later so that we can make loss curve later

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm

# plt.style.use('seaborn-v0_8-darkgrid')
plt.style.use('ggplot')

# %%
X, y = datasets.make_moons(n_samples = N_SAMPLE, # n_samples: how many datasets in it
                          noise = NOISE, # peportion of randommness added to data so that it matched to real life data , without noise it becomes perfect half circle in moon dataset
                          shuffle = True, 
                          random_state = RANDOM_STATE)
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %% [markdown]
# # one hidden layer

# %%
def sigmoid(x):
    return 1 / ( 1 + np.exp(-x))

# %%
def fn_actv(z):
    return np.tanh(z)

# %%
def fn_actv_prime(z):
    return 1-(np.tanh(z))**2

# %%
fn_actv(np.array([[-1,0,1],[-np.inf, 0, np.inf]]))
# Out:
# array([[-0.76159416,  0.        ,  0.76159416],
#        [-1.        ,  0.        ,  1.        ]])

# %%
def predict(model, X_p): # this function will work as activation function
    W1, b1, W2, b2= model['W1'], model['b1'], model['W2'], model['b2']
    m=X_p.shape[0]
    ## forward propagation
    #layer 1
    z1 = X_p.dot(W1) + b1  # aggregation function
    a1 = fn_actv(z1) # activation funvtion
    # Layer 2
    z2 = a1.dot(W2) + b2 # aggregation function for hidden layer
    a2 = sigmoid(z2) # activation
   
    return a2 >= 0.5

# %%
def fn_calculate_loss (model, X_l, y_l):
    W1, b1, W2, b2= model['W1'], model['b1'], model['W2'], model['b2']
    m=X_l.shape[0]
    ## forward propagation
    #layer 1
    z1 = X_l.dot(W1) + b1  # aggregation function
    a1 = fn_actv(z1) # activation funvtion
    # Layer 2
    z2 = a1.dot(W2) + b2 # aggregation function for hidden layer
    a2 = sigmoid(z2) # activation
    data_loss = -y_l* np.log(a2)
    return data_loss.sum()/m

# %%
# features_df = data_df.drop('target', axis=1)
# labels= data_df['target']

# %%
X_train, X_test, y_train, y_test=   train_test_split(X,y , random_state= RANDOM_STATE, stratify=y, test_size= TEST_SIZE)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((800, 2), (200, 2), (800,), (200,))

# %%
rng = np.random.default_rng(seed = RANDOM_STATE)

def build_model(nn_hdim, X_t, y_t, n_epoch = EPOCHS, alpha = ALPHA): # nn_hdim:- no of hidden layers 
    '''
    2-4-1
    '''
    # get dimensions for weight in it
    m, nn_input_dim = X_t.shape # m is no of rows
    nn_output_shape = y_t.shape[1]
    # initializing weighs randomly using numoy generator
    W1 = rng.random((nn_input_dim, nn_hdim), dtype= np.float32) / np.sqrt(nn_input_dim)
    W2 = rng.random((nn_hdim, nn_output_shape), dtype = np.float32)/ np.sqrt(nn_hdim)

    # initializing bias 
    b1 = np.zeros((1, nn_hdim), dtype = np.float32)
    b2 = np.zeros((1, nn_output_shape), dtype = np.float32)

    curr_loss = 0
    loss = []
    epoch = []
    for i in range(n_epoch):
        ## forward propagation
        #layer 1
        z1 = X_t.dot(W1) + b1  # aggregation function
        a1 = fn_actv(z1) # activation funvtion
        # Layer 2
        z2 = a1.dot(W2) + b2 # aggregation function for hidden layer
        a2 = sigmoid(z2) # activation

        ## backpropagation
        # print(y.shape)
        dz2 = a2 - y_t # y should be of shape (1, m)
        dW2 = (a1.T).dot(dz2)
        assert (W2.shape == dW2.shape), f'Shape: W2-{W2.shape} and dw2-{dW2.shape}'

        db2 = np.sum(dz2, axis = 0, keepdims = True)
        assert (b2.shape == db2.shape), f'Shape: b2-{b2.shape} and db2-{db2.shape}'
        da1 = dz2.dot(W2.T)
        assert (a1.shape == da1.shape), f'Shape: a1-{a1.shape} and da1-{da1.shape}'

        # layer 1
        dz1 = da1 * fn_actv_prime(z1)
        assert (z1.shape == dz1.shape), f'Shape: z1-{z1.shape} and dz1-{dz1.shape}'
        dW1 = (X_t.T).dot(dz1)
        assert (W1.shape== dW1.shape), f'Shape: W1-{W1.shape} and dW1-{dW1.shape}'
        db1= np.sum(dz1, axis=0, keepdims=True)
        assert (b1.shape== db1.shape), f'Shape: b1-{b1.shape} and db1-{db1.shape}'

        #### Gradient Updates

        W1 += - alpha *dW1/m
        W2 += - alpha *dW2/m
        b1 += - alpha *db1/m
        b2 += - alpha *db2/m
        model = {'W1':W1, 'b1': b1, 'W2': W2, 'b2' : b2}

        if i%100 == 0:
            curr_loss = fn_calculate_loss(model, X_t, y_t)
            loss.append(curr_loss)
            epoch.append(i)
            
        if i%1000 == 0:
            print(f'Loss after {i:>5d} epochs : {curr_loss:0.5f}')


    loss_hist['epoch'] = epoch
    loss_hist['loss'] = loss

    return model

# %%
model  = build_model(4, X_train, y_train.reshape(-1,1));
# Out:
# Loss after     0 epochs : 0.29173
# Loss after  1000 epochs : 0.14811
# Loss after  2000 epochs : 0.11359
# Loss after  3000 epochs : 0.07976
# Loss after  4000 epochs : 0.05990
# Loss after  5000 epochs : 0.04288
# Loss after  6000 epochs : 0.03557
# Loss after  7000 epochs : 0.03220
# Loss after  8000 epochs : 0.03051
# Loss after  9000 epochs : 0.02960
# Loss after 10000 epochs : 0.02906
# Loss after 11000 epochs : 0.02872
# Loss after 12000 epochs : 0.02849
# Loss after 13000 epochs : 0.02833
# Loss after 14000 epochs : 0.02822
# Loss after 15000 epochs : 0.02813
# Loss after 16000 epochs : 0.02806
# Loss after 17000 epochs : 0.02801
# Loss after 18000 epochs : 0.02795
# Loss after 19000 epochs : 0.02791
# Loss after 20000 epochs : 0.02786
# Loss after 21000 epochs : 0.02781
# Loss after 22000 epochs : 0.02776
# Loss after 23000 epochs : 0.02771
# Loss after 24000 epochs : 0.02766
# Loss after 25000 epochs : 0.02762
# Loss after 26000 epochs : 0.02757
# Loss after 27000 epochs : 0.02754
# Loss after 28000 epochs : 0.02750
# Loss after 29000 epochs : 0.02747
# Loss after 30000 epochs : 0.02744
# Loss after 31000 epochs : 0.02742
# Loss after 32000 epochs : 0.02739
# Loss after 33000 epochs : 0.02737
# Loss after 34000 epochs : 0.02735
# Loss after 35000 epochs : 0.02733
# Loss after 36000 epochs : 0.02731
# Loss after 37000 epochs : 0.02730
# Loss after 38000 epochs : 0.02728
# Loss after 39000 epochs : 0.02727
# Loss after 40000 epochs : 0.02726
# Loss after 41000 epochs : 0.02725
# Loss after 42000 epochs : 0.02723
# Loss after 43000 epochs : 0.02722
# Loss after 44000 epochs : 0.02721
# Loss after 45000 epochs : 0.02720
# Loss after 46000 epochs : 0.02720
# Loss after 47000 epochs : 0.02719
# Loss after 48000 epochs : 0.02718
# Loss after 49000 epochs : 0.02717
# Loss after 50000 epochs : 0.02716
# Loss after 51000 epochs : 0.02716
# Loss after 52000 epochs : 0.02715
# Loss after 53000 epochs : 0.02714
# Loss after 54000 epochs : 0.02713
# Loss after 55000 epochs : 0.02713
# Loss after 56000 epochs : 0.02712
# Loss after 57000 epochs : 0.02711
# Loss after 58000 epochs : 0.02710
# Loss after 59000 epochs : 0.02710
# Loss after 60000 epochs : 0.02709
# Loss after 61000 epochs : 0.02708
# Loss after 62000 epochs : 0.02708
# Loss after 63000 epochs : 0.02707
# Loss after 64000 epochs : 0.02706
# Loss after 65000 epochs : 0.02705
# Loss after 66000 epochs : 0.02705
# Loss after 67000 epochs : 0.02704
# Loss after 68000 epochs : 0.02703
# Loss after 69000 epochs : 0.02702
# Loss after 70000 epochs : 0.02702
# Loss after 71000 epochs : 0.02701
# Loss after 72000 epochs : 0.02700
# Loss after 73000 epochs : 0.02699
# Loss after 74000 epochs : 0.02699
# Loss after 75000 epochs : 0.02698
# Loss after 76000 epochs : 0.02697
# Loss after 77000 epochs : 0.02696
# Loss after 78000 epochs : 0.02696
# Loss after 79000 epochs : 0.02695
# Loss after 80000 epochs : 0.02694
# Loss after 81000 epochs : 0.02693
# Loss after 82000 epochs : 0.02693
# Loss after 83000 epochs : 0.02692
# Loss after 84000 epochs : 0.02691
# Loss after 85000 epochs : 0.02690
# Loss after 86000 epochs : 0.02690
# Loss after 87000 epochs : 0.02689
# Loss after 88000 epochs : 0.02688
# Loss after 89000 epochs : 0.02688
# Loss after 90000 epochs : 0.02687
# Loss after 91000 epochs : 0.02686
# Loss after 92000 epochs : 0.02685
# Loss after 93000 epochs : 0.02685
# Loss after 94000 epochs : 0.02684
# Loss after 95000 epochs : 0.02683
# Loss after 96000 epochs : 0.02683
# Loss after 97000 epochs : 0.02682
# Loss after 98000 epochs : 0.02681
# Loss after 99000 epochs : 0.02681

# %%
y_pred = predict(model, X_train)
accuracy_score(y_train, y_pred)
# Out:
# 0.98125

# %%
cm = confusion_matrix(y_train, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0,1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
y_pred = predict(model, X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.965

# %%
cm = confusion_matrix(y_test, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0, 1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
pd.DataFrame(loss_hist).plot(x= 'epoch', y = 'loss')
# Out:
# <Axes: xlabel='epoch'>

# %%
def fn_plot_decision_boundry(model, X, y, X_ts, y_ts): # x, y are trainig data, X_ts, y_ts are test data
    fig, ax = plt.subplots(figsize =(8,5))
    dm=0.01 # spacing of the grid width
    
    #Min and max along two axis
    x_min, x_max = X[:,0].min(), X[:,0].max()
    y_min, y_max = X[:,1].min(), X[:,1].max()

    # generate a mesh grid
    xx,yy = np.meshgrid(np.arange(x_min, x_max, dm), # creates an array of x-cordinates y no of times
                       np.arange(y_min, y_max, dm)) # creates an array of y-cordinates x no of times
    # Together they create a mesh\
    
    XX = np.c_[xx.ravel(), yy.ravel()]
    
    y_pred= predict(model, XX)

    
    Z = np.array(y_pred).reshape(xx.shape)

    ax.contourf(xx,yy, Z, alpha=0.8, cmap= plt.cm.Paired)
    ax.scatter(X[:,0], X[:,1], c = y, edgecolors='k', cmap= CMAP)
    ax.scatter(X_ts[:,0], X_ts[:,1], c = y_ts, edgecolors='k', cmap= CMAP,marker='*')

# %%
fn_plot_decision_boundry(model, X_train, y_train, X_test, y_test)

# %% [markdown]
# # with one neuron in hidden layer

# %%
model  = build_model(1, X_train, y_train.reshape(-1,1));
# Out:
# Loss after     0 epochs : 0.32727
# Loss after  1000 epochs : 0.15221
# Loss after  2000 epochs : 0.15012
# Loss after  3000 epochs : 0.14913
# Loss after  4000 epochs : 0.14856
# Loss after  5000 epochs : 0.14818
# Loss after  6000 epochs : 0.14791
# Loss after  7000 epochs : 0.14770
# Loss after  8000 epochs : 0.14753
# Loss after  9000 epochs : 0.14740
# Loss after 10000 epochs : 0.14729
# Loss after 11000 epochs : 0.14719
# Loss after 12000 epochs : 0.14710
# Loss after 13000 epochs : 0.14703
# Loss after 14000 epochs : 0.14697
# Loss after 15000 epochs : 0.14691
# Loss after 16000 epochs : 0.14686
# Loss after 17000 epochs : 0.14681
# Loss after 18000 epochs : 0.14677
# Loss after 19000 epochs : 0.14673
# Loss after 20000 epochs : 0.14669
# Loss after 21000 epochs : 0.14666
# Loss after 22000 epochs : 0.14663
# Loss after 23000 epochs : 0.14660
# Loss after 24000 epochs : 0.14657
# Loss after 25000 epochs : 0.14654
# Loss after 26000 epochs : 0.14652
# Loss after 27000 epochs : 0.14650
# Loss after 28000 epochs : 0.14648
# Loss after 29000 epochs : 0.14646
# Loss after 30000 epochs : 0.14644
# Loss after 31000 epochs : 0.14642
# Loss after 32000 epochs : 0.14640
# Loss after 33000 epochs : 0.14638
# Loss after 34000 epochs : 0.14637
# Loss after 35000 epochs : 0.14635
# Loss after 36000 epochs : 0.14634
# Loss after 37000 epochs : 0.14632
# Loss after 38000 epochs : 0.14631
# Loss after 39000 epochs : 0.14630
# Loss after 40000 epochs : 0.14629
# Loss after 41000 epochs : 0.14627
# Loss after 42000 epochs : 0.14626
# Loss after 43000 epochs : 0.14625
# Loss after 44000 epochs : 0.14624
# Loss after 45000 epochs : 0.14623
# Loss after 46000 epochs : 0.14622
# Loss after 47000 epochs : 0.14621
# Loss after 48000 epochs : 0.14620
# Loss after 49000 epochs : 0.14619
# Loss after 50000 epochs : 0.14618
# Loss after 51000 epochs : 0.14618
# Loss after 52000 epochs : 0.14617
# Loss after 53000 epochs : 0.14616
# Loss after 54000 epochs : 0.14615
# Loss after 55000 epochs : 0.14614
# Loss after 56000 epochs : 0.14614
# Loss after 57000 epochs : 0.14613
# Loss after 58000 epochs : 0.14612
# Loss after 59000 epochs : 0.14612
# Loss after 60000 epochs : 0.14611
# Loss after 61000 epochs : 0.14610
# Loss after 62000 epochs : 0.14610
# Loss after 63000 epochs : 0.14609
# Loss after 64000 epochs : 0.14609
# Loss after 65000 epochs : 0.14608
# Loss after 66000 epochs : 0.14607
# Loss after 67000 epochs : 0.14607
# Loss after 68000 epochs : 0.14606
# Loss after 69000 epochs : 0.14606
# Loss after 70000 epochs : 0.14605
# Loss after 71000 epochs : 0.14605
# Loss after 72000 epochs : 0.14604
# Loss after 73000 epochs : 0.14604
# Loss after 74000 epochs : 0.14603
# Loss after 75000 epochs : 0.14603
# Loss after 76000 epochs : 0.14602
# Loss after 77000 epochs : 0.14602
# Loss after 78000 epochs : 0.14601
# Loss after 79000 epochs : 0.14601
# Loss after 80000 epochs : 0.14601
# Loss after 81000 epochs : 0.14600
# Loss after 82000 epochs : 0.14600
# Loss after 83000 epochs : 0.14599
# Loss after 84000 epochs : 0.14599
# Loss after 85000 epochs : 0.14599
# Loss after 86000 epochs : 0.14598
# Loss after 87000 epochs : 0.14598
# Loss after 88000 epochs : 0.14597
# Loss after 89000 epochs : 0.14597
# Loss after 90000 epochs : 0.14597
# Loss after 91000 epochs : 0.14596
# Loss after 92000 epochs : 0.14596
# Loss after 93000 epochs : 0.14596
# Loss after 94000 epochs : 0.14595
# Loss after 95000 epochs : 0.14595
# Loss after 96000 epochs : 0.14595
# Loss after 97000 epochs : 0.14594
# Loss after 98000 epochs : 0.14594
# Loss after 99000 epochs : 0.14594

# %%
y_pred = predict(model, X_train)
accuracy_score(y_train, y_pred)
# Out:
# 0.8725

# %%
cm = confusion_matrix(y_train, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0,1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
y_pred = predict(model, X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.855

# %%
cm = confusion_matrix(y_test, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0, 1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
pd.DataFrame(loss_hist).plot(x= 'epoch', y = 'loss')
# Out:
# <Axes: xlabel='epoch'>

# %%
fn_plot_decision_boundry(model, X_train, y_train, X_test, y_test)

# %% [markdown]
# # with 10 neurons in hidden layer

# %%
model  = build_model(10, X_train, y_train.reshape(-1,1));
# Out:
# Loss after     0 epochs : 0.27371
# Loss after  1000 epochs : 0.12856
# Loss after  2000 epochs : 0.07648
# Loss after  3000 epochs : 0.05653
# Loss after  4000 epochs : 0.04711
# Loss after  5000 epochs : 0.04087
# Loss after  6000 epochs : 0.03669
# Loss after  7000 epochs : 0.03397
# Loss after  8000 epochs : 0.03214
# Loss after  9000 epochs : 0.03092
# Loss after 10000 epochs : 0.03010
# Loss after 11000 epochs : 0.02952
# Loss after 12000 epochs : 0.02910
# Loss after 13000 epochs : 0.02878
# Loss after 14000 epochs : 0.02853
# Loss after 15000 epochs : 0.02832
# Loss after 16000 epochs : 0.02815
# Loss after 17000 epochs : 0.02801
# Loss after 18000 epochs : 0.02789
# Loss after 19000 epochs : 0.02778
# Loss after 20000 epochs : 0.02769
# Loss after 21000 epochs : 0.02761
# Loss after 22000 epochs : 0.02754
# Loss after 23000 epochs : 0.02748
# Loss after 24000 epochs : 0.02743
# Loss after 25000 epochs : 0.02738
# Loss after 26000 epochs : 0.02734
# Loss after 27000 epochs : 0.02730
# Loss after 28000 epochs : 0.02726
# Loss after 29000 epochs : 0.02723
# Loss after 30000 epochs : 0.02720
# Loss after 31000 epochs : 0.02718
# Loss after 32000 epochs : 0.02715
# Loss after 33000 epochs : 0.02713
# Loss after 34000 epochs : 0.02711
# Loss after 35000 epochs : 0.02709
# Loss after 36000 epochs : 0.02707
# Loss after 37000 epochs : 0.02705
# Loss after 38000 epochs : 0.02704
# Loss after 39000 epochs : 0.02703
# Loss after 40000 epochs : 0.02701
# Loss after 41000 epochs : 0.02700
# Loss after 42000 epochs : 0.02699
# Loss after 43000 epochs : 0.02697
# Loss after 44000 epochs : 0.02696
# Loss after 45000 epochs : 0.02695
# Loss after 46000 epochs : 0.02694
# Loss after 47000 epochs : 0.02693
# Loss after 48000 epochs : 0.02692
# Loss after 49000 epochs : 0.02691
# Loss after 50000 epochs : 0.02691
# Loss after 51000 epochs : 0.02690
# Loss after 52000 epochs : 0.02689
# Loss after 53000 epochs : 0.02688
# Loss after 54000 epochs : 0.02687
# Loss after 55000 epochs : 0.02686
# Loss after 56000 epochs : 0.02685
# Loss after 57000 epochs : 0.02685
# Loss after 58000 epochs : 0.02684
# Loss after 59000 epochs : 0.02683
# Loss after 60000 epochs : 0.02682
# Loss after 61000 epochs : 0.02681
# Loss after 62000 epochs : 0.02680
# Loss after 63000 epochs : 0.02679
# Loss after 64000 epochs : 0.02678
# Loss after 65000 epochs : 0.02677
# Loss after 66000 epochs : 0.02676
# Loss after 67000 epochs : 0.02675
# Loss after 68000 epochs : 0.02674
# Loss after 69000 epochs : 0.02673
# Loss after 70000 epochs : 0.02672
# Loss after 71000 epochs : 0.02671
# Loss after 72000 epochs : 0.02670
# Loss after 73000 epochs : 0.02668
# Loss after 74000 epochs : 0.02667
# Loss after 75000 epochs : 0.02666
# Loss after 76000 epochs : 0.02665
# Loss after 77000 epochs : 0.02663
# Loss after 78000 epochs : 0.02662
# Loss after 79000 epochs : 0.02661
# Loss after 80000 epochs : 0.02659
# Loss after 81000 epochs : 0.02658
# Loss after 82000 epochs : 0.02657
# Loss after 83000 epochs : 0.02655
# Loss after 84000 epochs : 0.02654
# Loss after 85000 epochs : 0.02652
# Loss after 86000 epochs : 0.02651
# Loss after 87000 epochs : 0.02649
# Loss after 88000 epochs : 0.02648
# Loss after 89000 epochs : 0.02646
# Loss after 90000 epochs : 0.02644
# Loss after 91000 epochs : 0.02643
# Loss after 92000 epochs : 0.02641
# Loss after 93000 epochs : 0.02639
# Loss after 94000 epochs : 0.02637
# Loss after 95000 epochs : 0.02635
# Loss after 96000 epochs : 0.02634
# Loss after 97000 epochs : 0.02632
# Loss after 98000 epochs : 0.02630
# Loss after 99000 epochs : 0.02628

# %%
y_pred = predict(model, X_train)
accuracy_score(y_train, y_pred)
# Out:
# 0.98375

# %%
cm = confusion_matrix(y_train, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0,1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
y_pred = predict(model, X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.965

# %%
plost = ConfusionMatrixDisplay(cm, display_labels = [0, 1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
pd.DataFrame(loss_hist).plot(x= 'epoch', y = 'loss')
# Out:
# <Axes: xlabel='epoch'>

# %%
fn_plot_decision_boundry(model, X_train, y_train, X_test, y_test)

# %% [markdown]
# # with 50 neurons in hidden layer

# %%
model  = build_model(50, X_train, y_train.reshape(-1,1));
# Out:
# Loss after     0 epochs : 0.20663
# Loss after  1000 epochs : 0.13649
# Loss after  2000 epochs : 0.07659
# Loss after  3000 epochs : 0.04953
# Loss after  4000 epochs : 0.04131
# Loss after  5000 epochs : 0.03746
# Loss after  6000 epochs : 0.03523
# Loss after  7000 epochs : 0.03378
# Loss after  8000 epochs : 0.03277
# Loss after  9000 epochs : 0.03202
# Loss after 10000 epochs : 0.03143
# Loss after 11000 epochs : 0.03094
# Loss after 12000 epochs : 0.03053
# Loss after 13000 epochs : 0.03016
# Loss after 14000 epochs : 0.02983
# Loss after 15000 epochs : 0.02952
# Loss after 16000 epochs : 0.02924
# Loss after 17000 epochs : 0.02898
# Loss after 18000 epochs : 0.02875
# Loss after 19000 epochs : 0.02854
# Loss after 20000 epochs : 0.02835
# Loss after 21000 epochs : 0.02817
# Loss after 22000 epochs : 0.02802
# Loss after 23000 epochs : 0.02788
# Loss after 24000 epochs : 0.02775
# Loss after 25000 epochs : 0.02763
# Loss after 26000 epochs : 0.02752
# Loss after 27000 epochs : 0.02743
# Loss after 28000 epochs : 0.02734
# Loss after 29000 epochs : 0.02726
# Loss after 30000 epochs : 0.02718
# Loss after 31000 epochs : 0.02711
# Loss after 32000 epochs : 0.02704
# Loss after 33000 epochs : 0.02698
# Loss after 34000 epochs : 0.02692
# Loss after 35000 epochs : 0.02687
# Loss after 36000 epochs : 0.02682
# Loss after 37000 epochs : 0.02677
# Loss after 38000 epochs : 0.02672
# Loss after 39000 epochs : 0.02668
# Loss after 40000 epochs : 0.02664
# Loss after 41000 epochs : 0.02660
# Loss after 42000 epochs : 0.02656
# Loss after 43000 epochs : 0.02653
# Loss after 44000 epochs : 0.02650
# Loss after 45000 epochs : 0.02647
# Loss after 46000 epochs : 0.02644
# Loss after 47000 epochs : 0.02641
# Loss after 48000 epochs : 0.02638
# Loss after 49000 epochs : 0.02636
# Loss after 50000 epochs : 0.02633
# Loss after 51000 epochs : 0.02631
# Loss after 52000 epochs : 0.02628
# Loss after 53000 epochs : 0.02626
# Loss after 54000 epochs : 0.02624
# Loss after 55000 epochs : 0.02622
# Loss after 56000 epochs : 0.02620
# Loss after 57000 epochs : 0.02618
# Loss after 58000 epochs : 0.02617
# Loss after 59000 epochs : 0.02615
# Loss after 60000 epochs : 0.02613
# Loss after 61000 epochs : 0.02612
# Loss after 62000 epochs : 0.02610
# Loss after 63000 epochs : 0.02609
# Loss after 64000 epochs : 0.02608
# Loss after 65000 epochs : 0.02607
# Loss after 66000 epochs : 0.02606
# Loss after 67000 epochs : 0.02605
# Loss after 68000 epochs : 0.02604
# Loss after 69000 epochs : 0.02603
# Loss after 70000 epochs : 0.02602
# Loss after 71000 epochs : 0.02602
# Loss after 72000 epochs : 0.02601
# Loss after 73000 epochs : 0.02600
# Loss after 74000 epochs : 0.02600
# Loss after 75000 epochs : 0.02599
# Loss after 76000 epochs : 0.02599
# Loss after 77000 epochs : 0.02598
# Loss after 78000 epochs : 0.02598
# Loss after 79000 epochs : 0.02598
# Loss after 80000 epochs : 0.02597
# Loss after 81000 epochs : 0.02597
# Loss after 82000 epochs : 0.02596
# Loss after 83000 epochs : 0.02596
# Loss after 84000 epochs : 0.02595
# Loss after 85000 epochs : 0.02595
# Loss after 86000 epochs : 0.02594
# Loss after 87000 epochs : 0.02594
# Loss after 88000 epochs : 0.02593
# Loss after 89000 epochs : 0.02593
# Loss after 90000 epochs : 0.02592
# Loss after 91000 epochs : 0.02592
# Loss after 92000 epochs : 0.02591
# Loss after 93000 epochs : 0.02590
# Loss after 94000 epochs : 0.02590
# Loss after 95000 epochs : 0.02589
# Loss after 96000 epochs : 0.02589
# Loss after 97000 epochs : 0.02588
# Loss after 98000 epochs : 0.02588
# Loss after 99000 epochs : 0.02587

# %%
y_pred = predict(model, X_train)
accuracy_score(y_train, y_pred)
# Out:
# 0.98125

# %%
cm = confusion_matrix(y_train, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0,1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
y_pred = predict(model, X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.965

# %%
plost = ConfusionMatrixDisplay(cm, display_labels = [0, 1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
pd.DataFrame(loss_hist).plot(x= 'epoch', y = 'loss')
# Out:
# <Axes: xlabel='epoch'>

# %%
fn_plot_decision_boundry(model, X_train, y_train, X_test, y_test)
